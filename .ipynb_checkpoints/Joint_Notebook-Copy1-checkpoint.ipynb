# %%
# Dependencies
import json
import matplotlib.pyplot as plt
import requests
from pprint import pprint
from scipy import stats
import pandas as pd
from sodapy import Socrata

import numpy as np
from IPython.display import display
import datetime

# %%
# Specify URL
client = Socrata("data.cdc.gov", None)

# Make & store response
response = client.get("n8mc-b4w4", limit=1000000)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
# Make DataFrame
response_df = pd.DataFrame.from_records(response)
response_df.head(40)
# Out:
#    case_month res_state state_fips_code     res_county county_fips_code  \
# 0     2021-02        MD              24     MONTGOMERY            24031
# 1     2022-01        CA              06    SAN JOAQUIN            06077
# 2     2021-02        MA              25      MIDDLESEX            25017
# 3     2022-06        PA              42   PHILADELPHIA            42101
# 4     2021-01        TN              47       DAVIDSON            47037
# 5     2020-04        CA              06     SACRAMENTO            06067
# 6     2020-12        CA              06         FRESNO            06019
# 7     2021-08        NJ              34      MIDDLESEX            34023
# 8     2021-01        MA              25          ESSEX            25009
# 9     2020-12        CA              06         ORANGE            06059
# 10    2022-01        MN              27             NA               NA
# 11    2021-06        CO              08        EL PASO            08041
# 12    2021-11        WI              55      MILWAUKEE            55079
# 13    2020-12        NY              36          KINGS            36047
# 14    2022-01        AZ              04       MARICOPA            04013
# 15    2020-11        MI              26          WAYNE            26163
# 16    2020-11        OH              39       FRANKLIN            39049
# 17    2022-01        TX              48         HARRIS            48201
# 18    2020-08        IL              17           COOK            17031
# 19    2022-01        CA              06    LOS ANGELES            06037
# 20    2022-01        AZ              04           PIMA            04019
# 21    2021-04        CO              08       ARAPAHOE            08005
# 22    2022-07        CA              06   CONTRA COSTA            06013
# 23    2022-08        MI              26        OAKLAND            26125
# 24    2021-01        CA              06  SAN FRANCISCO            06075
# 25    2021-09        FL              12   HILLSBOROUGH            12057
# 26    2022-01        FL              12         ORANGE            12095
# 27    2021-01        FL              12        BROWARD            12011
# 28    2022-05        NY              36         MONROE            36055
# 29    2022-01        TX              48         DALLAS            48113
# 30    2021-02        FL              12          DUVAL            12031
# 31    2022-06        TX              48        TARRANT            48439
# 32    2020-12        CA              06      SAN DIEGO            06073
# 33    2022-01        TX              48         DENTON            48121
# 34    2021-04        PA              42      ALLEGHENY            42003
# 35    2020-12        NY              36         QUEENS            36081
# 36    2021-12        NY              36         NASSAU            36059
# 37    2021-08        NY              36           ERIE            36029
# 38    2021-12        FL              12     PALM BEACH            12099
# 39    2021-06        CO              08        EL PASO            08041
#
#          age_group     sex     race            ethnicity case_onset_interval  \
# 0   18 to 49 years    Male    White  Non-Hispanic/Latino                   0
# 1   18 to 49 years    Male       NA                   NA                 NaN
# 2   50 to 64 years    Male       NA                   NA                 NaN
# 3     0 - 17 years    Male  Unknown      Hispanic/Latino                 NaN
# 4   50 to 64 years    Male    White  Non-Hispanic/Latino                 NaN
# 5        65+ years    Male    White  Non-Hispanic/Latino                   0
# 6   18 to 49 years  Female  Unknown              Unknown                 NaN
# 7        65+ years    Male    White  Non-Hispanic/Latino                   0
# 8   18 to 49 years  Female       NA                   NA                 NaN
# 9   50 to 64 years    Male  Unknown              Unknown                 NaN
# 10  18 to 49 years  Female    White  Non-Hispanic/Latino                 NaN
# 11  18 to 49 years  Female    Black  Non-Hispanic/Latino                   0
# 12    0 - 17 years  Female    Black  Non-Hispanic/Latino                   0
# 13  18 to 49 years  Female    White  Non-Hispanic/Latino                   0
# 14  18 to 49 years    Male    White  Non-Hispanic/Latino                 NaN
# 15  18 to 49 years    Male    White  Non-Hispanic/Latino                 NaN
# 16  18 to 49 years    Male    Black  Non-Hispanic/Latino                   0
# 17    0 - 17 years  Female    White      Hispanic/Latino                 NaN
# 18  18 to 49 years  Female  Unknown      Hispanic/Latino                   0
# 19  18 to 49 years  Female    White      Hispanic/Latino                 NaN
# 20  50 to 64 years    Male    White      Hispanic/Latino                   0
# 21  18 to 49 years  Female    White      Hispanic/Latino                   0
# 22    0 - 17 years  Female  Unknown              Unknown                 NaN
# 23  18 to 49 years  Female  Unknown              Unknown                 NaN
# 24  18 to 49 years    Male    White              Unknown                 NaN
# 25  18 to 49 years  Female    White      Hispanic/Latino                 NaN
# 26    0 - 17 years    Male       NA                   NA                 NaN
# 27  50 to 64 years    Male       NA                   NA                   0
# 28  18 to 49 years  Female    Asian  Non-Hispanic/Latino                 NaN
# 29  18 to 49 years  Female    White  Non-Hispanic/Latino                 NaN
# 30  18 to 49 years  Female    White  Non-Hispanic/Latino                 NaN
# 31  18 to 49 years  Female  Missing      Hispanic/Latino                 NaN
# 32  50 to 64 years  Female  Unknown              Unknown                 NaN
# 33    0 - 17 years  Female  Missing              Missing                 NaN
# 34       65+ years    Male    White  Non-Hispanic/Latino                   0
# 35  18 to 49 years  Female  Unknown      Hispanic/Latino                   0
# 36  18 to 49 years    Male  Missing              Unknown                 NaN
# 37  18 to 49 years    Male    White  Non-Hispanic/Latino                   0
# 38       65+ years    Male       NA                   NA                   0
# 39  18 to 49 years  Female    Black  Non-Hispanic/Latino                   0
#
#                 process exposure_yn             current_status symptom_status  \
# 0               Missing     Missing  Laboratory-confirmed case    Symptomatic
# 1               Missing     Missing  Laboratory-confirmed case        Unknown
# 2               Missing     Missing  Laboratory-confirmed case        Missing
# 3               Missing     Missing              Probable Case        Unknown
# 4               Missing     Missing  Laboratory-confirmed case        Missing
# 5               Missing     Missing  Laboratory-confirmed case    Symptomatic
# 6               Missing     Missing  Laboratory-confirmed case        Unknown
# 7               Missing     Missing  Laboratory-confirmed case    Symptomatic
# 8               Missing     Missing  Laboratory-confirmed case        Missing
# 9               Missing     Missing  Laboratory-confirmed case        Unknown
# 10              Missing     Missing  Laboratory-confirmed case        Missing
# 11              Missing     Missing              Probable Case    Symptomatic
# 12              Missing     Missing  Laboratory-confirmed case    Symptomatic
# 13              Missing     Missing  Laboratory-confirmed case    Symptomatic
# 14              Missing     Missing  Laboratory-confirmed case        Missing
# 15              Missing     Missing  Laboratory-confirmed case        Missing
# 16  Clinical evaluation         Yes  Laboratory-confirmed case    Symptomatic
# 17              Missing     Missing  Laboratory-confirmed case        Missing
# 18              Missing     Missing  Laboratory-confirmed case        Missing
# 19              Missing     Missing  Laboratory-confirmed case        Unknown
# 20              Missing     Missing  Laboratory-confirmed case    Symptomatic
# 21              Missing     Missing  Laboratory-confirmed case    Symptomatic
# 22              Missing     Missing  Laboratory-confirmed case        Unknown
# 23              Missing     Missing  Laboratory-confirmed case        Missing
# 24              Missing     Missing  Laboratory-confirmed case        Unknown
# 25              Missing     Missing  Laboratory-confirmed case        Missing
# 26              Missing     Missing              Probable Case        Missing
# 27              Missing     Missing  Laboratory-confirmed case    Symptomatic
# 28              Missing     Missing  Laboratory-confirmed case        Missing
# 29              Missing     Missing  Laboratory-confirmed case        Missing
# 30              Missing     Missing  Laboratory-confirmed case        Missing
# 31              Missing     Missing              Probable Case        Missing
# 32              Missing     Missing  Laboratory-confirmed case        Unknown
# 33              Missing     Missing  Laboratory-confirmed case        Missing
# 34              Missing         Yes  Laboratory-confirmed case    Symptomatic
# 35              Missing     Missing  Laboratory-confirmed case    Symptomatic
# 36              Missing     Missing  Laboratory-confirmed case        Missing
# 37              Missing     Missing  Laboratory-confirmed case    Symptomatic
# 38              Missing     Missing  Laboratory-confirmed case    Symptomatic
# 39              Missing     Missing  Laboratory-confirmed case    Symptomatic
#
#     hosp_yn   icu_yn death_yn case_positive_specimen underlying_conditions_yn
# 0        No  Missing       No                    NaN                      NaN
# 1   Missing  Missing  Missing                    NaN                      NaN
# 2   Missing  Missing       No                      0                      NaN
# 3   Unknown  Unknown  Unknown                      0                      NaN
# 4   Missing  Missing  Missing                      0                      NaN
# 5       Yes       No  Missing                    NaN                      NaN
# 6   Missing  Missing  Missing                    NaN                      NaN
# 7        No  Missing       No                      1                      NaN
# 8   Missing  Missing  Missing                      0                      NaN
# 9   Missing  Missing  Missing                    NaN                      NaN
# 10  Missing  Missing       No                      0                      NaN
# 11       No  Missing  Missing                    NaN                      NaN
# 12       No  Missing       No                    NaN                      NaN
# 13  Missing  Missing  Missing                      0                      NaN
# 14  Missing  Missing  Missing                    NaN                      NaN
# 15  Missing  Missing  Unknown                    NaN                      NaN
# 16       No  Missing       No                    NaN                      NaN
# 17       No  Missing       No                    NaN                      NaN
# 18  Missing  Missing  Missing                    NaN                      NaN
# 19       No  Missing  Missing                    NaN                      NaN
# 20       No  Missing       No                    NaN                      NaN
# 21  Missing  Missing  Missing                    NaN                      NaN
# 22  Missing  Missing  Missing                    NaN                      NaN
# 23  Missing  Missing  Unknown                    NaN                      NaN
# 24  Missing  Missing  Missing                    NaN                      NaN
# 25  Missing  Missing  Missing                    NaN                      NaN
# 26  Missing  Missing  Missing                    NaN                      NaN
# 27       No  Missing       No                    NaN                      NaN
# 28  Missing  Missing       No                    NaN                      NaN
# 29  Missing  Missing  Missing                    NaN                      NaN
# 30  Missing  Missing  Missing                    NaN                      NaN
# 31  Missing  Missing  Missing                    NaN                      NaN
# 32  Missing  Missing  Missing                    NaN                      NaN
# 33  Missing  Missing  Missing                    NaN                      NaN
# 34       No  Unknown       No                      1                      NaN
# 35  Missing  Missing  Missing                      0                      Yes
# 36  Missing  Missing       No                    NaN                      NaN
# 37       No  Missing       No                    NaN                      NaN
# 38       No  Missing       No                      0                      NaN
# 39  Missing  Missing       No                    NaN                      NaN

# %%
# Create variable
case_count_by_state = response_df["res_state"].groupby(response_df["res_state"]).count()

# %%
# Sanity check
total_cases = case_count_by_state.sum()
total_cases
# Out:
# 1000000

# %%
# Total unique states
total_states = case_count_by_state.nunique()
total_states
# Out:
# 22

# %%
# Create Df showing cases in each state
cases_count_by_state_df = response_df[['res_state']]

cases_count_by_state_df['case_count'] = 0
cases_count_by_state_df = cases_count_by_state_df.groupby(['res_state'])['case_count'].agg('count').reset_index()
cases_count_by_state_df
# Out:
# C:\Users\cnr2231\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#    res_state  case_count
# 0         AL        8893
# 1         AZ       24138
# 2         CA      162339
# 3         CO       26666
# 4         FL       74382
# 5         GA       24137
# 6         IL       42215
# 7         IN       12068
# 8         MA       52630
# 9         MD       36205
# 10        MI       24138
# 11        MN       18103
# 12        MO       25103
# 13        NC       24136
# 14        NJ       68276
# 15        NV       12069
# 16        NY      120684
# 17        OH       36207
# 18        PA       24138
# 19        RI        6288
# 20        SC        8102
# 21        TN       24137
# 22        TX       72414
# 23        UT       24137
# 24        VA       12069
# 25        WA       30420
# 26        WI        5906

# %%
# Create variable to hold cases by month per state

cases_count_by_state_month_df = response_df[['res_state', 'case_month']]

cases_count_by_state_month_df['case_count'] = 0
cases_count_by_state_month_df = cases_count_by_state_month_df.groupby(['res_state','case_month'])['case_count'].agg('count').reset_index()
cases_count_by_state_month_df.head()
# Out:
# C:\Users\cnr2231\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
#   res_state case_month  case_count
# 0        AL    2020-03          29
# 1        AL    2020-04          28
# 2        AL    2020-06         723
# 3        AL    2020-07         138
# 4        AL    2020-08         189

# %%
us_state_to_abbrev = {
    "Alabama": "AL",
    "Alaska": "AK",
    "Arizona": "AZ",
    "Arkansas": "AR",
    "California": "CA",
    "Colorado": "CO",
    "Connecticut": "CT",
    "Delaware": "DE",
    "Florida": "FL",
    "Georgia": "GA",
    "Hawaii": "HI",
    "Idaho": "ID",
    "Illinois": "IL",
    "Indiana": "IN",
    "Iowa": "IA",
    "Kansas": "KS",
    "Kentucky": "KY",
    "Louisiana": "LA",
    "Maine": "ME",
    "Maryland": "MD",
    "Massachusetts": "MA",
    "Michigan": "MI",
    "Minnesota": "MN",
    "Mississippi": "MS",
    "Missouri": "MO",
    "Montana": "MT",
    "Nebraska": "NE",
    "Nevada": "NV",
    "New Hampshire": "NH",
    "New Jersey": "NJ",
    "New Mexico": "NM",
    "New York": "NY",
    "North Carolina": "NC",
    "North Dakota": "ND",
    "Ohio": "OH",
    "Oklahoma": "OK",
    "Oregon": "OR",
    "Pennsylvania": "PA",
    "Rhode Island": "RI",
    "South Carolina": "SC",
    "South Dakota": "SD",
    "Tennessee": "TN",
    "Texas": "TX",
    "Utah": "UT",
    "Vermont": "VT",
    "Virginia": "VA",
    "Washington": "WA",
    "West Virginia": "WV",
    "Wisconsin": "WI",
    "Wyoming": "WY",
    "District of Columbia": "DC",
    "American Samoa": "AS",
    "Guam": "GU",
    "Northern Mariana Islands": "MP",
    "Puerto Rico": "PR",
    "United States Minor Outlying Islands": "UM",
    "U.S. Virgin Islands": "VI",
}
    
# invert the dictionary
abbrev_to_us_state = dict(map(reversed, us_state_to_abbrev.items()))

# %%
abr_df = pd.DataFrame(abbrev_to_us_state.items(), columns=["res_state", "jurisdiction"])
abr_df.head()
# Out:
#   res_state jurisdiction
# 0        AL      Alabama
# 1        AK       Alaska
# 2        AZ      Arizona
# 3        AR     Arkansas
# 4        CA   California

# %%
cases_df = cases_count_by_state_df.merge(abr_df, how="inner")
cases_df.head()

#export
# Out:
#   res_state  case_count jurisdiction
# 0        AL        8893      Alabama
# 1        AZ       24138      Arizona
# 2        CA      162339   California
# 3        CO       26666     Colorado
# 4        FL       74382      Florida

# %%
#read moderna and pfizer data
moderna_df = pd.read_csv("Resources/cdc-moderna-covid-19-vaccine-distribution-by-state.csv")
pfizer_df = pd.read_csv("Resources/cdc-pfizer-covid-19-vaccine-distribution-by-state.csv")

#renaming identical column names
moderna_df = moderna_df.rename(columns={'_1st_dose_allocations': '1st_dose_Moderna',"_2nd_dose_allocations" :"2nd_dose_Moderna"})
#display(moderna_df)

pfizer_df = pfizer_df.rename(columns={'_1st_dose_allocations': '1st_dose_Pfizer',"_2nd_dose_allocations" :"2nd_dose_Pfizer"})
#display(pfizer_df)


vaccines_merge_df = moderna_df.merge(pfizer_df, how="left")
#display(vaccines_merge_df)

#have a proper date format for "week of allocations" columns
vaccines_merge_df[['Week_of_Allocations','Time']] = vaccines_merge_df.week_of_allocations.str.split("T",expand=True,)
vaccines_merge_df = vaccines_merge_df[["jurisdiction","1st_dose_Moderna","2nd_dose_Moderna","1st_dose_Pfizer","2nd_dose_Pfizer","Week_of_Allocations"]]

#export merged data to csv for business use
vaccines_merge_df.to_excel ('Output_Files/vaccines_merge_df.xlsx',header=True)

display(vaccines_merge_df)
# Out:
#          jurisdiction  1st_dose_Moderna  2nd_dose_Moderna  1st_dose_Pfizer  \
# 0         Connecticut             41220             41220            54360
# 1               Maine             15800             15800            21420
# 2       Massachusetts             79500             79500           104580
# 3       New Hampshire             15800             15800            21420
# 4        Rhode Island             12480             12480            17280
# ..                ...               ...               ...              ...
# 995            Hawaii             14200             14200            18720
# 996            Nevada             28500             28500            36270
# 997    American Samoa                 0                 0                0
# 998              Guam                 0                 0                0
# 999  Marshall Islands                 0                 0                0
#
#      2nd_dose_Pfizer Week_of_Allocations
# 0              54360          2021-06-21
# 1              21420          2021-06-21
# 2             104580          2021-06-21
# 3              21420          2021-06-21
# 4              17280          2021-06-21
# ..               ...                 ...
# 995            18720          2021-03-08
# 996            36270          2021-03-08
# 997                0          2021-03-08
# 998                0          2021-03-08
# 999                0          2021-03-08
#
# [1000 rows x 6 columns]

# %%
total_jurisdictions = vaccines_merge_df.groupby(['jurisdiction'])['1st_dose_Moderna', '2nd_dose_Moderna','1st_dose_Pfizer','2nd_dose_Pfizer'].agg('sum').reset_index()
display(total_jurisdictions)
# Out:
# C:\Users\cnr2231\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#       jurisdiction  1st_dose_Moderna  2nd_dose_Moderna  1st_dose_Pfizer  \
# 0          Alabama            834960            834960          1131930
# 1           Alaska            151860            151860           226440
# 2   American Samoa              5000                 0            11700
# 3          Arizona           1183560           1183560          1603440
# 4         Arkansas            506920            506920           691470
# ..             ...               ...               ...              ...
# 58        Virginia           1450280           1450280          1966500
# 59      Washington           1196520           1196520          1621890
# 60   West Virginia            323960            323960           442800
# 61       Wisconsin           1000800           1000800          1350090
# 62         Wyoming            100040            100040           145440
#
#     2nd_dose_Pfizer
# 0           1131930
# 1            214740
# 2                 0
# 3           1603440
# 4            691470
# ..              ...
# 58          1966500
# 59          1621890
# 60           442800
# 61          1350090
# 62           145440
#
# [63 rows x 5 columns]

# %%
#merge based on jurisdiction/state
cases_and_vaccinations_df = cases_df.merge(total_jurisdictions, how="inner")
display(cases_and_vaccinations_df)

#export
cases_and_vaccinations_df.to_excel('Output_Files/Cases_vs_Vaccinations_df.xlsx',header=True)
# Out:
#    res_state  case_count    jurisdiction  1st_dose_Moderna  2nd_dose_Moderna  \
# 0         AL        8893         Alabama            834960            834960
# 1         AZ       24138         Arizona           1183560           1183560
# 2         CA      162339      California           6658300           6658300
# 3         CO       26666        Colorado            946800            946800
# 4         FL       74382         Florida           3642160           3642160
# 5         GA       24137         Georgia           1726760           1726760
# 6         IL       42215        Illinois           1728160           1728160
# 7         IN       12068         Indiana           1122040           1122040
# 8         MA       52630   Massachusetts           1208000           1208000
# 9         MD       36205        Maryland           1033200           1033200
# 10        MI       24138        Michigan           1719000           1719000
# 11        MN       18103       Minnesota            942120            942120
# 12        MO       25103        Missouri           1042160           1042160
# 13        NC       24136  North Carolina           1742040           1742040
# 14        NJ       68276      New Jersey           1529920           1529920
# 15        NV       12069          Nevada            499160            499160
# 16        NY      120684        New York           1948840           1948840
# 17        OH       36207            Ohio           1998760           1998760
# 18        PA       24138    Pennsylvania           1968900           1968900
# 19        RI        6288    Rhode Island            189080            189080
# 20        SC        8102  South Carolina            855120            855120
# 21        TN       24137       Tennessee           1140960           1140960
# 22        TX       72414           Texas           4559940           4559940
# 23        UT       24137            Utah            474320            474320
# 24        VA       12069        Virginia           1450280           1450280
# 25        WA       30420      Washington           1196520           1196520
# 26        WI        5906       Wisconsin           1000800           1000800
#
#     1st_dose_Pfizer  2nd_dose_Pfizer
# 0           1131930          1131930
# 1           1603440          1603440
# 2           8980920          8980920
# 3           1283220          1283220
# 4           4910130          4910130
# 5           2336580          2336580
# 6           2336580          2336580
# 7           1517850          1517850
# 8           1637460          1637460
# 9           1401120          1401120
# 10          2317230          2317230
# 11          1276200          1276200
# 12          1408770          1408770
# 13          2352420          2352420
# 14          2066220          2066220
# 15           675630           675630
# 16          2624580          2624580
# 17          2700180          2700180
# 18          2662650          2662650
# 19           261000           261000
# 20          1162440          1162440
# 21          1547730          1547730
# 22          6149340          6149340
# 23           643410           643410
# 24          1966500          1966500
# 25          1621890          1621890
# 26          1350090          1350090
