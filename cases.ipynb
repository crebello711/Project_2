# %%
# Dependencies
import json
import matplotlib.pyplot as plt
import requests
from pprint import pprint
from scipy import stats
import pandas as pd
from sodapy import Socrata

# %%
# Specify URL
client = Socrata("data.cdc.gov", None)

# Make & store response
response = client.get("n8mc-b4w4", limit=500000)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
# Make DataFrame
response_df = pd.DataFrame.from_records(response)
response_df.head(5)
# Out:
#   case_month res_state state_fips_code  res_county county_fips_code  \
# 0    2022-06        NY              36      ULSTER            36111
# 1    2020-12        GA              13        HALL            13139
# 2    2021-09        IA              19    WOODBURY            19193
# 3    2020-11        KS              20     SHAWNEE            20177
# 4    2022-05        PA              42  WASHINGTON            42125
#
#         age_group     sex   race            ethnicity              process  \
# 0  18 to 49 years    Male  White              Unknown              Missing
# 1  18 to 49 years  Female  White      Hispanic/Latino              Missing
# 2  18 to 49 years  Female  Black  Non-Hispanic/Latino              Missing
# 3    0 - 17 years  Female  White  Non-Hispanic/Latino  Laboratory reported
# 4  18 to 49 years  Female  White  Non-Hispanic/Latino              Missing
#
#   exposure_yn             current_status symptom_status  hosp_yn   icu_yn  \
# 0     Missing  Laboratory-confirmed case        Missing  Missing  Missing
# 1     Missing  Laboratory-confirmed case    Symptomatic  Missing  Missing
# 2     Missing  Laboratory-confirmed case    Symptomatic  Missing  Missing
# 3         Yes  Laboratory-confirmed case    Symptomatic       No  Missing
# 4     Missing  Laboratory-confirmed case    Symptomatic  Unknown  Unknown
#
#   death_yn case_onset_interval case_positive_specimen underlying_conditions_yn
# 0       No                 NaN                    NaN                      NaN
# 1  Missing                   0                    NaN                      NaN
# 2  Missing                   0                    NaN                      NaN
# 3       No                   0                      0                      NaN
# 4  Unknown                   0                      1                      NaN

# %%
# Create variable
case_count_by_state = response_df["res_state"].groupby(response_df["res_state"]).count()

# %%
# Sanity check
total_cases = case_count_by_state.sum()
total_cases
# Out:
# 500000

# %%
# Total unique states
total_states = case_count_by_state.nunique()
total_states
# Out:
# 46

# %%
# Create Df showing cases in each state
case_count_by_state_df = pd.DataFrame({
    "Case Count": case_count_by_state    
})
case_count_by_state_df
# Out:
#            Case Count
# res_state
# AK               1778
# AL              14216
# AR               8599
# AZ               7110
# CA              24786
# CO               8886
# CT               4145
# DC                592
# DE               1779
# FL              22514
# GA              18955
# HI               1777
# IA               4146
# ID               3556
# IL              16033
# IN              15996
# KS               4737
# KY               6013
# LA              12140
# MA               6517
# MD              10071
# ME               3018
# MI              16277
# MN               9956
# MO              10661
# MS                104
# MT               3555
# NC              33929
# ND               2370
# NE               1778
# NH               3645
# NJ              12438
# NM               6517
# NV               1776
# NY              21920
# OH              25469
# OK               3555
# OR               8890
# PA              24291
# RI               2370
# SC              14407
# SD               1185
# TN              20575
# TX              28593
# UT               4148
# VA              16567
# VT                593
# WA              10665
# WI              15195
# WY               1207

# %%
# Create variable to hold cases by month per state
cases_count_by_state_month = response_df[["res_state","case_month"]].value_counts().sort_index()
cases_count_by_state_month
# Out:
# res_state  case_month
# AZ         2021-01       1
#            2022-01       1
# CA         2020-08       1
#            2021-02       1
#            2022-02       2
# FL         2020-07       1
# IL         2021-12       1
# NC         2021-11       1
# TX         2022-08       1
# dtype: int64

# %%
# Create Df showing cases in each state by month
cases_count_by_state_month_df = pd.DataFrame({
    "Cases by month": cases_count_by_state_month
})
cases_count_by_state_month_df.head(5)
# Out:
#                       Cases by month
# res_state case_month
# AZ        2021-01                  1
#           2022-01                  1
# CA        2020-08                  1
#           2021-02                  1
#           2022-02                  2
