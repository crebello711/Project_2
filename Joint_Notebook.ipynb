# %%
# Dependencies
import json
import matplotlib.pyplot as plt
import requests
from pprint import pprint
from scipy import stats
import pandas as pd
from sodapy import Socrata

import numpy as np
from IPython.display import display

# %%
# Specify URL
client = Socrata("data.cdc.gov", None)

# Make & store response
response = client.get("n8mc-b4w4", limit=1000000)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
# Make DataFrame
response_df = pd.DataFrame.from_records(response)
response_df.head()
# Out:
#   case_month res_state state_fips_code  res_county county_fips_code  \
# 0    2021-12        PA              42  LACKAWANNA            42069
# 1    2021-08        FL              12  MIAMI-DADE            12086
# 2    2021-08        IL              17  WILLIAMSON            17199
# 3    2022-03        AL              01     BALDWIN            01003
# 4    2022-07        NC              37      WILKES            37193
#
#         age_group     sex   race            ethnicity case_positive_specimen  \
# 0    0 - 17 years    Male  White      Hispanic/Latino                      0
# 1  18 to 49 years    Male  White      Hispanic/Latino                    NaN
# 2  18 to 49 years  Female  White  Non-Hispanic/Latino                      0
# 3  50 to 64 years  Female  White  Non-Hispanic/Latino                    NaN
# 4       65+ years  Female  White  Non-Hispanic/Latino                      1
#
#   case_onset_interval  process exposure_yn             current_status  \
# 0                   0  Missing     Missing  Laboratory-confirmed case
# 1                 NaN  Missing     Missing  Laboratory-confirmed case
# 2                   0  Missing     Missing  Laboratory-confirmed case
# 3                 NaN  Missing     Missing  Laboratory-confirmed case
# 4                   0  Missing     Missing              Probable Case
#
#   symptom_status  hosp_yn   icu_yn death_yn underlying_conditions_yn
# 0    Symptomatic  Unknown  Unknown  Unknown                      NaN
# 1        Missing       No  Missing       No                      NaN
# 2        Missing  Missing  Missing  Missing                      NaN
# 3        Missing  Missing  Missing  Missing                      NaN
# 4    Symptomatic       No  Unknown       No                      Yes

# %%
# Create variable
case_count_by_state = response_df["res_state"].groupby(response_df["res_state"]).count()

# %%
# Sanity check
total_cases = case_count_by_state.sum()
total_cases
# Out:
# 1000000

# %%
# Total unique states
total_states = case_count_by_state.nunique()
total_states
# Out:
# 45

# %%
# Create Df showing cases in each state
cases_count_by_state_df = response_df[['res_state']]

cases_count_by_state_df['case_count'] = 0
cases_count_by_state_df = cases_count_by_state_df.groupby(['res_state'])['case_count'].agg('count').reset_index()
cases_count_by_state_df.head()
# Out:
# /var/folders/_d/fz71ty6n6l98qqqdl6qnkfc40000gn/T/ipykernel_77371/3274174806.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cases_count_by_state_df['case_count'] = 0
#   res_state  case_count
# 0        AK        3086
# 1        AL       28118
# 2        AR       14124
# 3        AZ       15427
# 4        CA       55534

# %%
# Create variable to hold cases by month per state

cases_count_by_state_month_df = response_df[['res_state', 'case_month']]

cases_count_by_state_month_df['case_count'] = 0
cases_count_by_state_month_df = cases_count_by_state_month_df.groupby(['res_state','case_month'])['case_count'].agg('count').reset_index()
cases_count_by_state_month_df.head()
# Out:
# /var/folders/_d/fz71ty6n6l98qqqdl6qnkfc40000gn/T/ipykernel_77371/2683122176.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cases_count_by_state_month_df['case_count'] = 0
#   res_state case_month  case_count
# 0        AK    2020-06          11
# 1        AK    2020-07          41
# 2        AK    2020-08          74
# 3        AK    2020-09         112
# 4        AK    2020-10         293

# %%
us_state_to_abbrev = {
    "Alabama": "AL",
    "Alaska": "AK",
    "Arizona": "AZ",
    "Arkansas": "AR",
    "California": "CA",
    "Colorado": "CO",
    "Connecticut": "CT",
    "Delaware": "DE",
    "Florida": "FL",
    "Georgia": "GA",
    "Hawaii": "HI",
    "Idaho": "ID",
    "Illinois": "IL",
    "Indiana": "IN",
    "Iowa": "IA",
    "Kansas": "KS",
    "Kentucky": "KY",
    "Louisiana": "LA",
    "Maine": "ME",
    "Maryland": "MD",
    "Massachusetts": "MA",
    "Michigan": "MI",
    "Minnesota": "MN",
    "Mississippi": "MS",
    "Missouri": "MO",
    "Montana": "MT",
    "Nebraska": "NE",
    "Nevada": "NV",
    "New Hampshire": "NH",
    "New Jersey": "NJ",
    "New Mexico": "NM",
    "New York": "NY",
    "North Carolina": "NC",
    "North Dakota": "ND",
    "Ohio": "OH",
    "Oklahoma": "OK",
    "Oregon": "OR",
    "Pennsylvania": "PA",
    "Rhode Island": "RI",
    "South Carolina": "SC",
    "South Dakota": "SD",
    "Tennessee": "TN",
    "Texas": "TX",
    "Utah": "UT",
    "Vermont": "VT",
    "Virginia": "VA",
    "Washington": "WA",
    "West Virginia": "WV",
    "Wisconsin": "WI",
    "Wyoming": "WY",
    "District of Columbia": "DC",
    "American Samoa": "AS",
    "Guam": "GU",
    "Northern Mariana Islands": "MP",
    "Puerto Rico": "PR",
    "United States Minor Outlying Islands": "UM",
    "U.S. Virgin Islands": "VI",
}
    
# invert the dictionary
abbrev_to_us_state = dict(map(reversed, us_state_to_abbrev.items()))

# %%
abr_df = pd.DataFrame(abbrev_to_us_state.items(), columns=["res_state", "jurisdiction"])
abr_df.head()
# Out:
#   res_state jurisdiction
# 0        AL      Alabama
# 1        AK       Alaska
# 2        AZ      Arizona
# 3        AR     Arkansas
# 4        CA   California

# %%
cases_df = cases_count_by_state_df.merge(abr_df, how="inner")
cases_df.head()
# Out:
#   res_state  case_count jurisdiction
# 0        AK        3086       Alaska
# 1        AL       28118      Alabama
# 2        AR       14124     Arkansas
# 3        AZ       15427      Arizona
# 4        CA       55534   California

# %%
#read moderna and pfizer data
moderna_df = pd.read_csv("Resources/cdc-moderna-covid-19-vaccine-distribution-by-state.csv")
pfizer_df = pd.read_csv("Resources/cdc-pfizer-covid-19-vaccine-distribution-by-state.csv")

# %%
moderna_df.head()
# Out:
#     jurisdiction      week_of_allocations  _1st_dose_allocations  \
# 0    Connecticut  2021-06-21T00:00:00.000                  41220
# 1          Maine  2021-06-21T00:00:00.000                  15800
# 2  Massachusetts  2021-06-21T00:00:00.000                  79500
# 3  New Hampshire  2021-06-21T00:00:00.000                  15800
# 4   Rhode Island  2021-06-21T00:00:00.000                  12480
#
#    _2nd_dose_allocations
# 0                  41220
# 1                  15800
# 2                  79500
# 3                  15800
# 4                  12480

# %%
pfizer_df.head()
# Out:
#     jurisdiction      week_of_allocations  _1st_dose_allocations  \
# 0    Connecticut  2021-06-21T00:00:00.000                  54360
# 1          Maine  2021-06-21T00:00:00.000                  21420
# 2  Massachusetts  2021-06-21T00:00:00.000                 104580
# 3  New Hampshire  2021-06-21T00:00:00.000                  21420
# 4   Rhode Island  2021-06-21T00:00:00.000                  17280
#
#    _2nd_dose_allocations
# 0                  54360
# 1                  21420
# 2                 104580
# 3                  21420
# 4                  17280

# %%
vaccines_merge_df = moderna_df.merge(pfizer_df, how="left")
vaccines_merge_df.head()
# Out:
#     jurisdiction      week_of_allocations  _1st_dose_allocations  \
# 0    Connecticut  2021-06-21T00:00:00.000                  41220
# 1          Maine  2021-06-21T00:00:00.000                  15800
# 2  Massachusetts  2021-06-21T00:00:00.000                  79500
# 3  New Hampshire  2021-06-21T00:00:00.000                  15800
# 4   Rhode Island  2021-06-21T00:00:00.000                  12480
#
#    _2nd_dose_allocations
# 0                  41220
# 1                  15800
# 2                  79500
# 3                  15800
# 4                  12480

# %%
vaccines_merge_clean_df = vaccines_merge_df[["jurisdiction", "_1st_dose_allocations", "_2nd_dose_allocations"]]
vaccines_merge_clean_df.head()
# Out:
#     jurisdiction  _1st_dose_allocations  _2nd_dose_allocations
# 0    Connecticut                  41220                  41220
# 1          Maine                  15800                  15800
# 2  Massachusetts                  79500                  79500
# 3  New Hampshire                  15800                  15800
# 4   Rhode Island                  12480                  12480

# %%
total_jurisdictions = vaccines_merge_clean_df.groupby(['jurisdiction'])['_1st_dose_allocations', '_2nd_dose_allocations'].agg('sum').reset_index()
total_jurisdictions.head()
# Out:
# /var/folders/_d/fz71ty6n6l98qqqdl6qnkfc40000gn/T/ipykernel_77371/3357132712.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   total_jurisdictions = vaccines_merge_clean_df.groupby(['jurisdiction'])['_1st_dose_allocations', '_2nd_dose_allocations'].agg('sum').reset_index()
#      jurisdiction  _1st_dose_allocations  _2nd_dose_allocations
# 0         Alabama                 834960                 834960
# 1          Alaska                 151860                 151860
# 2  American Samoa                   5000                      0
# 3         Arizona                1183560                1183560
# 4        Arkansas                 506920                 506920

# %%
cases_and_vaccinations_df = cases_df.merge(total_jurisdictions, how="inner")
cases_and_vaccinations_df.head()
# Out:
#   res_state  case_count jurisdiction  _1st_dose_allocations  \
# 0        AK        3086       Alaska                 151860
# 1        AL       28118      Alabama                 834960
# 2        AR       14124     Arkansas                 506920
# 3        AZ       15427      Arizona                1183560
# 4        CA       55534   California                6658300
#
#    _2nd_dose_allocations
# 0                 151860
# 1                 834960
# 2                 506920
# 3                1183560
# 4                6658300

# %%
cases_and_vaccinations_clean_df = cases_and_vaccinations_df[["res_state", "case_count", "_1st_dose_allocations","_2nd_dose_allocations"]]
cases_and_vaccinations_clean_df
# Out:
#    res_state  case_count  _1st_dose_allocations  _2nd_dose_allocations
# 0         AK        3086                 151860                 151860
# 1         AL       28118                 834960                 834960
# 2         AR       14124                 506920                 506920
# 3         AZ       15427                1183560                1183560
# 4         CA       55534                6658300                6658300
# 5         CO       16971                 946800                 946800
# 6         CT        6170                 626920                 626920
# 7         DC        1543                 126120                 126120
# 8         DE        4629                 166240                 166240
# 9         FL       50906                3642160                3642160
# 10        GA       39520                1726760                1726760
# 11        HI        3084                 248160                 248160
# 12        IA        4628                 533000                 533000
# 13        ID        8805                 261720                 261720
# 14        IL       35486                1728160                1728160
# 15        IN       31805                1122040                1122040
# 16        KS        7750                 486760                 486760
# 17        KY        9255                 759560                 759560
# 18        LA       25877                 788080                 788080
# 19        MA       16969                1208000                1208000
# 20        MD       21954                1033200                1033200
# 21        ME        7715                 239800                 239800
# 22        MI       30850                1719000                1719000
# 23        MN       18675                 942120                 942120
# 24        MO       21755                1042160                1042160
# 25        MT        7446                 182360                 182360
# 26        NC       63250                1742040                1742040
# 27        ND        5323                 131200                 131200
# 28        NE        4626                 322120                 322120
# 29        NH        6169                 240200                 240200
# 30        NJ       30852                1529920                1529920
# 31        NM        9316                 359400                 359400
# 32        NV        3085                 499160                 499160
# 33        NY       47824                1948840                1948840
# 34        OH       47994                1998760                1998760
# 35        OK        6172                 656880                 656880
# 36        OR       15426                 674760                 674760
# 37        PA       49744                1968900                1968900
# 38        RI        4628                 189080                 189080
# 39        SC       31629                 855120                 855120
# 40        SD        3086                 145880                 145880
# 41        TN       31362                1140960                1140960
# 42        TX       58621                4559940                4559940
# 43        UT        9710                 474320                 474320
# 44        VA       28265                1450280                1450280
# 45        VT        1543                 113480                 113480
# 46        WA       22679                1196520                1196520
# 47        WI       27529                1000800                1000800
# 48        WY        3085                 100040                 100040

# %%
cases_and_vaccinations_clean_df.to_csv('out.csv')
